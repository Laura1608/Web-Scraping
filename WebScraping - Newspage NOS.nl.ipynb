# %% [markdown]
# # Web Scraping

# %%
# !pip install requests
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
# Out:
# Requirement already satisfied: requests in c:\users\laura\anaconda3\envs\dataanalytics\lib\site-packages (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\laura\anaconda3\envs\dataanalytics\lib\site-packages (from requests) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\laura\anaconda3\envs\dataanalytics\lib\site-packages (from requests) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laura\anaconda3\envs\dataanalytics\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laura\anaconda3\envs\dataanalytics\lib\site-packages (from requests) (2022.12.7)

# %% [markdown]
# ### Obtain list of news from the coverpage

# %% [markdown]
# URL definition:

# %%
# url definition
url = "https://nos.nl/"

# %% [markdown]
# List of news:

# %%
# Request
requests.get(url)
# Out:
# <Response [200]>

# %%
# We'll save in coverpage the cover page content
coverpage = requests.get(url).content

# %%
soup = BeautifulSoup(coverpage, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="nl"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><style>
#     #nprogress {
#       pointer-events: none;
#     }
#     #nprogress .bar {
#       background: #e61e14;
#       position: fixed;
#       z-index: 9999;
#       top: 0;
#       left: 0;
#       width: 100%;
#       height: 3px;
#     }
#     #nprogress .peg {
#       display: block;
#       position: absolute;
#       right: 0px;
#       width: 100px;
#       height: 100%;
#       box-shadow: 0 0 10px #e61e14, 0 0 5px #e61e14;
#       opacity: 1;
#       -webkit-transform: rotate(3deg) translate(0px, -4px);
#       -ms-transform: rotate(3deg) translate(0px, -4px);
#       transform: rotate(3deg) translate(0px, -4px);
#     }
#     #nprogress .spinner {
#       display: block;
#       position: fixed;
#       z-index: 1031;
#       top: 15px;
#       right: 15px;
#     }
#     #nprogress .spinner-icon {
#       width: 18px;
#       height: 18px;
#       box-sizing: border-box;
#       border: solid 2px transparent;
#       border-top-color: #e61e14;
#       border-left-color: #e61e14;
#       border-radius: 50%;
#       -webkit-animation: nprogresss-spinner 400ms linear infinite;
#       animation: nprogress-spinner 400ms linear infinite;
#     }
#     .nprogress-custom-parent {
#       overflow: hidden;
#       position: relative;
#     }
#     .nprogress-custom-parent #nprogress .spinner,
#     .nprogress-custom-parent #nprogress .bar {
#       position: absolute;
#     }
#     @-webkit-keyframes nprogress-spinner {
#       0% {
#         -webkit-transform: rotate(0deg);
#       }
#       100% {
#         -webkit-transform: rotate(360deg);
#       }
#     }
#     @keyframes nprogress-spinner {
#       0% {
#         transform: rotate(0deg);
#       }
#       100% {
#         transform: rotate(360deg);
#       }
#     }
#   </style><title>NOS.nl - Nieuws, Sport en Evenementen | Nederlandse Omroep Stichting</title><link href="https://nos.nl" rel="canonical"/><meta content="NOS.nl - Nieuws, Sport en Evenementen op Radio, TV en Internet" name="description"/><meta content="Nederlandse Omroep Stichting" name="title"/><meta content="website" property="og:type"/><meta content="https://nos.nl/" property="og:url"/><meta content="Nederlandse Omroep Stichting" property="og:title"/><meta content="NOS.nl - Nieuws, Sport en Evenementen op Radio, TV en Internet" property="og:description"/><meta content="https://static.nos.nl/img/nos/nos-social.jpg" property="og:image"/><meta content="1200" property="og:image:width"/><meta content="630" property="og:image:height"/><meta content="app" property="twitter:card"/><meta content="@NOS" property="twitter:site"/><meta content="https://static.nos.nl/img/nos/nos-social.jpg" name="thumbnail"/><meta content="id516491461" property="twitter:app:id:iphone"/><meta content="nl.nos.app://open" property="twitter:app:url:iphone"/><meta content="id516491461" property="twitter:app:id:ipad"/><meta content="nl" property="twitter:app:country"/><meta content="nl.nos.app://open" property="twitter:app:url:ipad"/><meta content="nl.nos.app" property="twitter:app:id:googleplay"/><link href="https://static.nos.nl/img/favicon/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><link href="https://static.nos.nl/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="https://static.nos.nl/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link color="#e61e14" href="https://static.nos.nl/img/favicon/safari-pinned-tab.svg" rel="mask-icon"/><link href="https://static.nos.nl/img/favicon/favicon.ico" rel="shortcut icon"/><meta content="NOS.nl" name="apple-mobile-web-app-title"/><meta content="NOS.nl" name="application-name"/><meta content="#ffffff" name="msapplication-TileColor"/><meta content="#ffffff" name="theme-color"/><link href="/static/site.webmanifest" rel="manifest"/><meta content="/static/browserconfig.xml" name="msapplication-config"/><meta content="34" name="next-head-count"/><meta content="PFlpDv56X7yQ8CtMDAxvMIyOWtfO8puTcDbndM0veTY" name="google-site-verification"/><meta content="NOS" name="app-name"/><meta content="app-id=516491461" name="apple-itunes-app"/><meta content="app-id=nl.nos.app" name="google-play-app"/><script>var hasWindowAndDocument = !!(typeof window !== 'undefined' && document);
#             if (hasWindowAndDocument && !!window.MSInputMethodContext && !!document.documentMode) {
#               if (window.location.pathname !== '/geen-ondersteuning') {
#                 window.location.replace(window.location.origin + '/geen-ondersteuning');
#               }
#             }</script><noscript data-n-css=""></noscript><script defer="" nomodule="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/webpack-026a9aec3722d733.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/framework-069452382afcb148.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/main-9c1056773f66bba3.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/pages/_app-a9b76ddb82493ff2.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/413057b3-da9785c34e9b86f5.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/7479-cf84b95c84265a38.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/4410-fbc51a02194f77d9.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/3866-9b02efe487295cbb.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/6758-5e2db6fb9f51adec.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/1108-dee68e473a24ad3b.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/200-a8bdcf4b71cfb211.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/4852-0bb4372856a3ec5f.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/91-ed20eae316f8b4be.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/6022-d0fdf568a1d6daf1.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/6206-89c1805703938028.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/822-7ab781ec432ca602.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/5702-5e27a8328ce63d2b.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/5888-a1e71a4f1f70de73.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/7302-0c96d4234dc51af5.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/chunks/pages/index-19d2f444c53f2cc3.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/WXp9dwa28oJyfJyBYjo5v/_buildManifest.js"></script><script defer="" src="https://cdn.nos.nl/assets/nosnl/c7d228e/_next/static/WXp9dwa28oJyfJyBYjo5v/_ssgManifest.js"></script><style id="__jsx-undefined">
#           @font-face {
#             font-family: 'Effra-Bold';
#             font-style: normal;
#             font-display: block;
#             font-weight: 700;
#             src: local('EffraBold'), local('EffraBold'),
#               url('https://static.nos.nl/fonts/effra/EffraBold.woff?v=prod-app') format('woff'),
#               url('https://static.nos.nl/fonts/effra/EffraBold.woff2?v=prod-app') format('woff2');
#           }
#
#           @font-face {
#             font-family: 'Karla';
#             font-style: normal;
#             font-display: block;
#             font-weight: 400;
#             src: local('Karla'), local('Karla'),
#               url('https://static.nos.nl/fonts/karla/Karla-Regular.ttf?v=prod-app') format('truetype');
#           }
#
#           @font-face {
#             font-family: 'Karla';
#             font-style: italic;
#             font-display: block;
#             font-weight: 400;
#             src: local('Karla'), local('Karla'),
#               url('https://static.nos.nl/fonts/karla/Karla-Italic.ttf?v=prod-app') format('truetype');
#           }
#
#           @font-face {
#             font-family: 'Karla';
#             font-style: normal;
#             font-display: block;
#             font-weight: 700;
#             src: local('Karla'), local('Karla'),
#               url('https://static.nos.nl/fonts/karla/Karla-Bold.ttf?v=prod-app') format('truetype');
#           }
#
#           @font-face {
#             font-family: 'Merriweather';
#             font-style: normal;
#             font-display: block;
#             font-weight: 700;
#             src: local('Merriweather'), local('Merriweather'),
#               url('https://static.nos.nl/fonts/merriweather/Merriweather-Bold.ttf?v=prod-app') format('truetype');
#           }
#
#           @font-face {
#             font-family: 'Qatar2022';
#             font-style: normal;
#             font-display: block;
#             font-weight: 700;
#             src: local('Qatar2022'), local('Qatar2022'),
#               url('https://static.nos.nl/fonts/wk2022/Qatar2022-Bold.otf?v=prod-app') format('opentype');
#           }
#         </style><style data-styled="" data-styled-version="5.3.6">html{line-height:1.15;-webkit-text-size-adjust:100%;}/*!sc*/
# body{margin:0;}/*!sc*/
# main{display:block;}/*!sc*/
# h1{font-size:2em;margin:0.67em 0;}/*!sc*/
# hr{box-sizing:content-box;height:0;overflow:visible;}/*!sc*/
# pre{font-family:monospace,monospace;font-size:1em;}/*!sc*/
# a{background-color:transparent;}/*!sc*/
# abbr[title]{border-bottom:none;-webkit-text-decoration:underline;text-decoration:underline;-webkit-text-decoration:underline dotted;text-decoration:underline dotted;}/*!sc*/
# b,strong{font-weight:bolder;}/*!sc*/
# code,kbd,samp{font-family:monospace,monospace;font-size:1em;}/*!sc*/
# small{font-size:80%;}/*!sc*/
# sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline;}/*!sc*/
# sub{bottom:-0.25em;}/*!sc*/
# sup{top:-0.5em;}/*!sc*/
# img{border-style:none;}/*!sc*/
# button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0;}/*!sc*/
# button,input{overflow:visible;}/*!sc*/
# button,select{text-transform:none;}/*!sc*/
# button,[type="button"],[type="reset"],[type="submit"]{-webkit-appearance:button;}/*!sc*/
# button::-moz-focus-inner,[type="button"]::-moz-focus-inner,[type="reset"]::-moz-focus-inner,[type="submit"]::-moz-focus-inner{border-style:none;padding:0;}/*!sc*/
# button:-moz-focusring,[type="button"]:-moz-focusring,[type="reset"]:-moz-focusring,[type="submit"]:-moz-focusring{outline:1px dotted ButtonText;}/*!sc*/
# fieldset{padding:0.35em 0.75em 0.625em;}/*!sc*/
# legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal;}/*!sc*/
# progress{vertical-align:baseline;}/*!sc*/
# textarea{overflow:auto;}/*!sc*/
# [type="checkbox"],[type="radio"]{box-sizing:border-box;padding:0;}/*!sc*/
# [type="number"]::-webkit-inner-spin-button,[type="number"]::-webkit-outer-spin-button{height:auto;}/*!sc*/
# [type="search"]{-webkit-appearance:textfield;outline-offset:-2px;}/*!sc*/
# [type="search"]::-webkit-search-decoration{-webkit-appearance:none;}/*!sc*/
# ::-webkit-file-upload-button{-webkit-appearance:button;font:inherit;}/*!sc*/
# details{display:block;}/*!sc*/
# summary{display:list-item;}/*!sc*/
# template{display:none;}/*!sc*/
# [hidden]{display:none;}/*!sc*/
# data-styled.g5[id="sc-global-ecVvVt1"]{content:"sc-global-ecVvVt1,"}/*!sc*/
# *,*:before,*:after{box-sizing:border-box;}/*!sc*/
# html,body{height:100%;-webkit-text-size-adjust:100%;-webkit-tap-highlight-color:transparent;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;text-rendering:optimizeLegibility;font-feature-settings:"liga","kern";font-family:"Helvetica Neue",Helvetica,Arial,sans-serif;font-size:1rem;}/*!sc*/
# body{-webkit-scroll-behavior:smooth;-moz-scroll-behavior:smooth;-ms-scroll-behavior:smooth;scroll-behavior:smooth;}/*!sc*/
# .usabilla_live_button_container{display:none;}/*!sc*/
# data-styled.g6[id="sc-global-bEnFVD1"]{content:"sc-global-bEnFVD1,"}/*!sc*/
# .XPeck{overflow-wrap:anywhere;margin:0;padding:0;font-weight:700;font-size:2.125rem;line-height:1.2;}/*!sc*/
# data-styled.g7[id="sc-773b561e-0"]{content:"XPeck,"}/*!sc*/
# .jwmpfU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border:0;border-radius:50%;background-color:#fff;color:white;-webkit-text-decoration:none;text-decoration:none;font-weight:700;font-size:0.875rem;cursor:pointer;-webkit-transition:-webkit-transform 250ms ease-in-out;-webkit-transition:transform 250ms ease-in-out;transition:transform 250ms ease-in-out;background-color:#fff;width:3.75rem;height:3.75rem;box-shadow:rgba(0,0,0,0.2) 0 0.125rem 0.625rem 0;}/*!sc*/
# .jwmpfU:hover{-webkit-transform:scale(1.06);-ms-transform:scale(1.06);transform:scale(1.06);}/*!sc*/
# .jwmpfU svg{width:28px;height:23px;-webkit-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);color:#e61e14;}/*!sc*/
# .bTCccR{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border:0;border-radius:50%;background-color:#fff;color:white;-webkit-text-decoration:none;text-decoration:none;font-weight:700;font-size:0.875rem;cursor:pointer;-webkit-transition:-webkit-transform 250ms ease-in-out;-webkit-transition:transform 250ms ease-in-out;transition:transform 250ms ease-in-out;background-color:#fff;width:3.75rem;height:3.75rem;box-shadow:rgba(0,0,0,0.2) 0 0.125rem 0.625rem 0;}/*!sc*/
# .bTCccR:hover{-webkit-transform:scale(1.06);-ms-transform:scale(1.06);transform:scale(1.06);}/*!sc*/
# .bTCccR svg{width:28px;height:23px;color:#e61e14;}/*!sc*/
# data-styled.g8[id="sc-d9ef4f17-0"]{content:"jwmpfU,bTCccR,"}/*!sc*/
# .bRxKDw{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;max-width:100%;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;font-family:'Effra-Bold',Helvetica,Arial,sans-serif;font-weight:500;border-radius:3.5rem;background-color:#e61e14;color:#fff;-webkit-backdrop-filter:blur(0);backdrop-filter:blur(0);-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .bRxKDw svg{display:inline-block;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;vertical-align:middle;line-height:1;fill:currentColor;width:1em;height:1em;}/*!sc*/
# .bRxKDw svg + *{margin-left:0.36em;}/*!sc*/
# data-styled.g12[id="sc-577f6030-0"]{content:"bRxKDw,"}/*!sc*/
# .cMNAXz{-webkit-font-smoothing:antialiased;-webkit-backface-visibility:hidden;backface-visibility:hidden;display:inline-block;overflow:hidden;vertical-align:middle;text-overflow:ellipsis;white-space:nowrap;line-height:1;-webkit-transform:translateZ(0);-ms-transform:translateZ(0);transform:translateZ(0);}/*!sc*/
# data-styled.g13[id="sc-577f6030-1"]{content:"cMNAXz,"}/*!sc*/
# .kDMmdZ{position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;top:0;right:0;bottom:0;left:0;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;z-index:1;-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}/*!sc*/
# data-styled.g14[id="sc-7bbb3d29-0"]{content:"kDMmdZ,"}/*!sc*/
# .PkRtd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:0 1 auto;-ms-flex:0 1 auto;flex:0 1 auto;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;width:100%;}/*!sc*/
# .jpVprA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:0 1 auto;-ms-flex:0 1 auto;flex:0 1 auto;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;width:100%;}/*!sc*/
# data-styled.g15[id="sc-e6b42465-0"]{content:"PkRtd,jpVprA,"}/*!sc*/
# .eKBpig{position:relative;z-index:0;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;overflow:hidden;border-radius:0.22rem;}/*!sc*/
# data-styled.g16[id="sc-e6b42465-1"]{content:"eKBpig,"}/*!sc*/
# .jfsjMQ{margin:0;padding:0;}/*!sc*/
# data-styled.g17[id="sc-e6b42465-2"]{content:"jfsjMQ,"}/*!sc*/
# .jzyTwN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;margin:0;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .jzyTwN .sc-577f6030-0{margin:0.25rem auto 0.25rem 0;padding:0;background-color:transparent;color:#e61e14;text-transform:uppercase;-webkit-letter-spacing:0.0625rem;-moz-letter-spacing:0.0625rem;-ms-letter-spacing:0.0625rem;letter-spacing:0.0625rem;}/*!sc*/
# .jzyTwN .sc-577f6030-0 .sc-577f6030-1{padding-top:2px;}/*!sc*/
# .jzyTwN .sc-577f6030-0 svg path{color:#e61e14;}/*!sc*/
# @media (min-width:760px){.jzyTwN{-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}}/*!sc*/
# data-styled.g18[id="sc-e6b42465-3"]{content:"jzyTwN,"}/*!sc*/
# .dypUEp{overflow-wrap:anywhere;position:relative;z-index:1;margin:0;padding:0;color:#222222;text-align:left;-webkit-transition:color 250ms ease-in-out;transition:color 250ms ease-in-out;}/*!sc*/
# data-styled.g19[id="sc-2d866c3b-0"]{content:"dypUEp,"}/*!sc*/
# .jPkGEE{overflow-wrap:anywhere;display:none;margin:0.5rem 0 0;color:#666666;line-height:1.25rem;}/*!sc*/
# @media (min-width:760px){.jPkGEE{display:block;}}/*!sc*/
# data-styled.g20[id="sc-2d866c3b-1"]{content:"jPkGEE,"}/*!sc*/
# .bTcZed{position:absolute;border-radius:50%;background-color:rgba(0,0,0,0.2);}/*!sc*/
# .bTcZed svg{width:1rem;height:1rem;}/*!sc*/
# .bTcZed svg path{color:white;}/*!sc*/
# data-styled.g21[id="sc-2d866c3b-2"]{content:"bTcZed,"}/*!sc*/
# .caEZmW{position:absolute;right:0;bottom:0;left:0;}/*!sc*/
# .caEZmW:before{position:absolute;top:0;left:0;z-index:1;display:block;width:100%;height:100%;background-image:linear-gradient(rgba(0,0,0,0) 25%,rgba(0,0,0,0.7));content:'';}/*!sc*/
# .caEZmW .sc-577f6030-0{position:relative;z-index:1;}/*!sc*/
# data-styled.g22[id="sc-2d866c3b-3"]{content:"caEZmW,"}/*!sc*/
# .qTpqt{position:absolute;top:0;right:0;bottom:0;left:0;width:100%;height:100%;}/*!sc*/
# data-styled.g24[id="sc-8e313b0a-0"]{content:"qTpqt,"}/*!sc*/
# .dGrJDt{object-fit:cover;position:absolute;top:0;right:0;bottom:0;left:0;width:100%;height:100%;background-color:#f3f3f0;}/*!sc*/
# data-styled.g25[id="sc-8e313b0a-1"]{content:"dGrJDt,"}/*!sc*/
# .eWdgdw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row nowrap;-ms-flex-flow:row nowrap;flex-flow:row nowrap;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:1.0rem 1.0rem 1.0rem 0;}/*!sc*/
# .eWdgdw > svg:first-child{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;width:3.0rem;}/*!sc*/
# data-styled.g26[id="sc-5cd663f0-0"]{content:"eWdgdw,"}/*!sc*/
# .hPtdRB{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;margin-left:1.0rem;}/*!sc*/
# data-styled.g27[id="sc-5cd663f0-1"]{content:"hPtdRB,"}/*!sc*/
# .huusnw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:0 0 3.0rem;-ms-flex:0 0 3.0rem;flex:0 0 3.0rem;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:3.0rem;height:3.0rem;border-radius:50%;background-color:#f3f3f0;}/*!sc*/
# .huusnw svg{color:#e61e14;}/*!sc*/
# data-styled.g28[id="sc-5cd663f0-2"]{content:"huusnw,"}/*!sc*/
# .gQPQwf{display:block;margin-bottom:0.25rem;color:#222222;font-weight:500;font-size:1rem;line-height:1;}/*!sc*/
# data-styled.g29[id="sc-5cd663f0-3"]{content:"gQPQwf,"}/*!sc*/
# .dJMxbv{display:block;color:#666666;font-size:0.875rem;}/*!sc*/
# data-styled.g30[id="sc-5cd663f0-4"]{content:"dJMxbv,"}/*!sc*/
# .jxQGBA{overflow-wrap:anywhere;display:block;color:#666666;-webkit-text-decoration:none;text-decoration:none;font-weight:500;line-height:1.14;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;}/*!sc*/
# @media (hover:hover) and (pointer:fine),only screen and (-ms-high-contrast:active),(-ms-high-contrast:none){.jxQGBA:hover{color:#e61e14;}.jxQGBA:hover .sc-5cd663f0-3{color:inherit;}.jxQGBA:hover .sc-5cd663f0-5{-webkit-transform:translate(0.1em,-0.1em);-ms-transform:translate(0.1em,-0.1em);transform:translate(0.1em,-0.1em);}}/*!sc*/
# .jxQGBA:active{color:#e61e14;-webkit-transition:none;transition:none;}/*!sc*/
# .jxQGBA:active .sc-5cd663f0-3{color:inherit;}/*!sc*/
# data-styled.g32[id="sc-47af2b69-0"]{content:"jxQGBA,"}/*!sc*/
# .gweKva{margin-top:2.5rem;border-top:1px solid #eee;border-bottom:1px solid #eee;background-color:#fff;color:#666666;}/*!sc*/
# data-styled.g33[id="sc-d6783ec5-0"]{content:"gweKva,"}/*!sc*/
# .gxSBYh{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# @media (min-width:760px){.gxSBYh{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;max-width:75rem;margin:0 auto;padding:2rem 1.0rem 0;}}/*!sc*/
# data-styled.g34[id="sc-d6783ec5-1"]{content:"gxSBYh,"}/*!sc*/
# .fwGVQK{overflow-wrap:anywhere;margin:1.0rem 0;color:#e61e14;font-weight:500;font-size:1.125rem;font-family:'Effra-Bold',Helvetica,Arial,sans-serif;}/*!sc*/
# data-styled.g35[id="sc-d6783ec5-2"]{content:"fwGVQK,"}/*!sc*/
# .eNRHXl{margin:1.0rem 0 0;padding:0;list-style:none;}/*!sc*/
# data-styled.g36[id="sc-d6783ec5-3"]{content:"eNRHXl,"}/*!sc*/
# .kTWCaj{display:inline-block;margin-bottom:1.0rem;color:#666666;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0.01875rem;-moz-letter-spacing:0.01875rem;-ms-letter-spacing:0.01875rem;letter-spacing:0.01875rem;font-weight:500;line-height:1.13;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;}/*!sc*/
# @media (hover:hover) and (pointer:fine),only screen and (-ms-high-contrast:active),(-ms-high-contrast:none){.kTWCaj:hover{color:#e61e14;}}/*!sc*/
# .kTWCaj:active{color:#e61e14;}/*!sc*/
# data-styled.g37[id="sc-d6783ec5-4"]{content:"kTWCaj,"}/*!sc*/
# .cnWHLB{-webkit-flex-shrink:2;-ms-flex-negative:2;flex-shrink:2;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media (min-width:760px){.cnWHLB{padding-top:2rem;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:18.75rem;-ms-flex-preferred-size:18.75rem;flex-basis:18.75rem;display:none;}}/*!sc*/
# .fEkBld{-webkit-flex-shrink:2;-ms-flex-negative:2;flex-shrink:2;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;display:none;}/*!sc*/
# @media (min-width:760px){.fEkBld{padding-top:2rem;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:18.75rem;-ms-flex-preferred-size:18.75rem;flex-basis:18.75rem;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}/*!sc*/
# data-styled.g38[id="sc-d6783ec5-5"]{content:"cnWHLB,fEkBld,"}/*!sc*/
# .RkEJx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:0 2rem 2rem;border-top:1px solid #eee;}/*!sc*/
# @media (min-width:760px){.RkEJx{width:100%;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;padding:2rem 1.0rem 2rem 0;border-top:0;}}/*!sc*/
# @media (min-width:900px){.RkEJx{padding:2rem 5rem 2rem 0;}}/*!sc*/
# data-styled.g39[id="sc-d6783ec5-6"]{content:"RkEJx,"}/*!sc*/
# .cypYXt{display:none;margin-right:2.5rem;}/*!sc*/
# .cypYXt:first-child{display:block;}/*!sc*/
# @media (min-width:760px){.cypYXt{display:block;}}/*!sc*/
# data-styled.g40[id="sc-d6783ec5-7"]{content:"cypYXt,"}/*!sc*/
# .ldTzGh{border-top:1px solid #eee;}/*!sc*/
# data-styled.g41[id="sc-d6783ec5-8"]{content:"ldTzGh,"}/*!sc*/
# .cNxKBM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding-top:2rem;}/*!sc*/
# @media (min-width:760px){.cNxKBM{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;max-width:75rem;margin:0 auto;padding:0 1.0rem;}}/*!sc*/
# data-styled.g42[id="sc-d6783ec5-9"]{content:"cNxKBM,"}/*!sc*/
# .irVARc{padding:1.0rem 2rem;border-bottom:1px solid #eee;}/*!sc*/
# @media (min-width:760px){.irVARc{padding:1.0rem 1.0rem 1.0rem 0;}}/*!sc*/
# .irVARc:last-child{border-bottom:0;}/*!sc*/
# .irVARc .sc-5cd663f0-0{padding:0;}/*!sc*/
# data-styled.g43[id="sc-d6783ec5-10"]{content:"irVARc,"}/*!sc*/
# .hJcrLQ{padding:1.0rem 2rem;border:none;border-bottom:1px solid #eee;background:none;text-align:left;font-weight:500;cursor:pointer;}/*!sc*/
# @media (min-width:760px){.hJcrLQ{padding:1.0rem 1.0rem 1.0rem 0;}}/*!sc*/
# .hJcrLQ:hover .sc-5cd663f0-3{color:#e61e14;}/*!sc*/
# .hJcrLQ .sc-5cd663f0-0{padding:0;}/*!sc*/
# data-styled.g44[id="sc-d6783ec5-11"]{content:"hJcrLQ,"}/*!sc*/
# .ifjdgR{-webkit-transition:-webkit-transform 150ms ease-in-out;-webkit-transition:transform 150ms ease-in-out;transition:transform 150ms ease-in-out;}/*!sc*/
# .ifjdgR:hover{-webkit-transform:scale(1.025);-ms-transform:scale(1.025);transform:scale(1.025);}/*!sc*/
# .ifjdgR svg{color:#949494;}/*!sc*/
# data-styled.g45[id="sc-d6783ec5-12"]{content:"ifjdgR,"}/*!sc*/
# .gpFWdC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;width:100%;padding:1.5625rem 2rem;margin-top:1.0rem;font-weight:500;border-top:1px solid #eee;}/*!sc*/
# @media (min-width:760px){.gpFWdC{-webkit-order:1;-ms-flex-order:1;order:1;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;margin-left:3.125rem;margin-top:0;border-top:0;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;padding:2rem 0;}}/*!sc*/
# data-styled.g46[id="sc-d6783ec5-13"]{content:"gpFWdC,"}/*!sc*/
# .elYnSD{color:#666666;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .elYnSD:hover{color:#e61e14;}/*!sc*/
# data-styled.g47[id="sc-d6783ec5-14"]{content:"elYnSD,"}/*!sc*/
# .wFKir{font-size:1rem;}/*!sc*/
# @media (min-width:760px){.wFKir{margin-right:2rem;}}/*!sc*/
# data-styled.g48[id="sc-d6783ec5-15"]{content:"wFKir,"}/*!sc*/
# .gfxhYP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:2rem;height:2rem;border-radius:50%;background-color:#000;color:#fff;opacity:1;-webkit-transition:-webkit-transform 150ms ease-in-out;-webkit-transition:transform 150ms ease-in-out;transition:transform 150ms ease-in-out;}/*!sc*/
# .gfxhYP:hover{-webkit-transform:scale(1.0625);-ms-transform:scale(1.0625);transform:scale(1.0625);}/*!sc*/
# .gfxhYP svg{-webkit-transform:scale(0.8);-ms-transform:scale(0.8);transform:scale(0.8);}/*!sc*/
# data-styled.g49[id="sc-87002ce1-0"]{content:"gfxhYP,"}/*!sc*/
# .cqDOEQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-top:0.6875rem;}/*!sc*/
# @media (min-width:760px){.cqDOEQ{-webkit-order:3;-ms-flex-order:3;order:3;margin-top:0;}}/*!sc*/
# data-styled.g50[id="sc-ec8ded51-0"]{content:"cqDOEQ,"}/*!sc*/
# .irtWkE{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;margin:0.625rem;background-color:#e61e14;}/*!sc*/
# @media (min-width:760px){.irtWkE{margin-right:0;margin-left:1.25rem;}}/*!sc*/
# data-styled.g51[id="sc-ec8ded51-1"]{content:"irtWkE,"}/*!sc*/
# .bgWHdH{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;}/*!sc*/
# data-styled.g56[id="sc-9611602e-0"]{content:"bgWHdH,"}/*!sc*/
# .hKubVh{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;padding:0 0.5rem;color:#e61e14;-webkit-text-decoration:none;text-decoration:none;font-size:1rem;font-weight:500;-webkit-letter-spacing:0.0167rem;-moz-letter-spacing:0.0167rem;-ms-letter-spacing:0.0167rem;letter-spacing:0.0167rem;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;background-color:#fff;border:none;}/*!sc*/
# .hKubVh:hover{color:#e61e14;}/*!sc*/
# .hKubVh:focus{outline-offset:-2px;}/*!sc*/
# @media (min-width:600px){.hKubVh{padding:0 1.0rem;}}/*!sc*/
# @media (min-width:1100px){.hKubVh{padding:0 1.25rem;font-size:1.125em;}}/*!sc*/
# .glorxf{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;padding:0 0.5rem;color:#666666;-webkit-text-decoration:none;text-decoration:none;font-size:1rem;font-weight:500;-webkit-letter-spacing:0.0167rem;-moz-letter-spacing:0.0167rem;-ms-letter-spacing:0.0167rem;letter-spacing:0.0167rem;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;background-color:#fff;border:none;}/*!sc*/
# .glorxf:hover{color:#e61e14;}/*!sc*/
# .glorxf:focus{outline-offset:-2px;}/*!sc*/
# @media (min-width:600px){.glorxf{padding:0 1.0rem;}}/*!sc*/
# @media (min-width:1100px){.glorxf{padding:0 1.25rem;font-size:1.125em;}}/*!sc*/
# data-styled.g57[id="sc-9611602e-1"]{content:"hKubVh,glorxf,"}/*!sc*/
# .cIVuPK{z-index:999;padding:0 0.5rem;height:4.375rem;background-color:#fff;box-shadow:0 0.125rem 0.25rem 0 rgba(0,0,0,0.12);position:-webkit-sticky;position:sticky;top:0;}/*!sc*/
# @media (min-width:760px){.cIVuPK{position:-webkit-sticky;position:sticky;top:0;padding:0;}@media (min-width:760px){.cIVuPK{margin-bottom:2rem;}}}/*!sc*/
# @media (min-width:900px){.cIVuPK{margin-bottom:2.5rem;}}/*!sc*/
# data-styled.g58[id="sc-8392139e-0"]{content:"cIVuPK,"}/*!sc*/
# .jrkmva{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:0 auto;max-width:75rem;}/*!sc*/
# data-styled.g59[id="sc-8392139e-1"]{content:"jrkmva,"}/*!sc*/
# .dGiiYh{width:auto;height:1.25rem;}/*!sc*/
# data-styled.g60[id="sc-58aba6b1-0"]{content:"dGiiYh,"}/*!sc*/
# .bkSzFs{width:auto;height:1.25rem;-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# data-styled.g61[id="sc-58aba6b1-1"]{content:"bkSzFs,"}/*!sc*/
# .gxTnrQ{width:0.5rem;margin:0.25rem 0 0 0.25rem;}/*!sc*/
# data-styled.g62[id="sc-58aba6b1-2"]{content:"gxTnrQ,"}/*!sc*/
# .kyjLHA{display:block;height:4.375rem;}/*!sc*/
# @media (min-width:900px){.kyjLHA{display:none;}}/*!sc*/
# data-styled.g63[id="sc-58aba6b1-3"]{content:"kyjLHA,"}/*!sc*/
# .UzeJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;margin:0;padding:0;height:100%;list-style:none;}/*!sc*/
# data-styled.g64[id="sc-58aba6b1-4"]{content:"UzeJ,"}/*!sc*/
# .degBui{position:relative;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#666666;}/*!sc*/
# data-styled.g65[id="sc-58aba6b1-5"]{content:"degBui,"}/*!sc*/
# .czWaks:before{margin:0 0.25rem;width:1px;height:1.5rem;border-left:1px solid #ddd;content:'';}/*!sc*/
# data-styled.g66[id="sc-58aba6b1-6"]{content:"czWaks,"}/*!sc*/
# .kclyEz{display:block;padding:0.5rem;color:#949494;-webkit-transition:-webkit-transform 150ms ease-in-out;-webkit-transition:transform 150ms ease-in-out;transition:transform 150ms ease-in-out;}/*!sc*/
# @media (min-width:600px){.kclyEz{padding:1.0rem;}}/*!sc*/
# .kclyEz svg{display:block;width:65px;}/*!sc*/
# @media (max-width:375px){.kclyEz svg{width:55px;}}/*!sc*/
# .kclyEz:hover{-webkit-transform:scale(1.025);-ms-transform:scale(1.025);transform:scale(1.025);}/*!sc*/
# data-styled.g67[id="sc-58aba6b1-7"]{content:"kclyEz,"}/*!sc*/
# .jpTAwY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 0.5rem;color:#666666;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0.0167rem;-moz-letter-spacing:0.0167rem;-ms-letter-spacing:0.0167rem;letter-spacing:0.0167rem;font-weight:500;font-size:1rem;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;}/*!sc*/
# .jpTAwY:hover{color:#e61e14;}/*!sc*/
# data-styled.g68[id="sc-58aba6b1-8"]{content:"jpTAwY,"}/*!sc*/
# .jeLLXQ{width:30px;height:auto;}/*!sc*/
# @media (min-width:1100px){.jeLLXQ{width:32px;}}/*!sc*/
# data-styled.g69[id="sc-74c2715c-0"]{content:"jeLLXQ,"}/*!sc*/
# .dVOyyV{width:22px;height:auto;}/*!sc*/
# @media (min-width:1100px){.dVOyyV{width:24px;}}/*!sc*/
# data-styled.g70[id="sc-74c2715c-1"]{content:"dVOyyV,"}/*!sc*/
# .hdLwFa{width:33px;height:auto;}/*!sc*/
# @media (min-width:1100px){.hdLwFa{width:36px;}}/*!sc*/
# data-styled.g71[id="sc-74c2715c-2"]{content:"hdLwFa,"}/*!sc*/
# .bUOjgf{width:22px;height:auto;-webkit-transform:rotate(90deg);-ms-transform:rotate(90deg);transform:rotate(90deg);}/*!sc*/
# @media (min-width:1100px){.bUOjgf{width:24px;}}/*!sc*/
# data-styled.g72[id="sc-74c2715c-3"]{content:"bUOjgf,"}/*!sc*/
# .fJbVnU{width:0.5em;margin:0.25em 0 0 0.25em;}/*!sc*/
# data-styled.g73[id="sc-74c2715c-4"]{content:"fJbVnU,"}/*!sc*/
# .kbxTIv{width:70px;color:#949494;}/*!sc*/
# data-styled.g74[id="sc-74c2715c-5"]{content:"kbxTIv,"}/*!sc*/
# .lfhtKZ{display:none;height:4.375rem;}/*!sc*/
# @media (min-width:900px){.lfhtKZ{display:block;}}/*!sc*/
# data-styled.g75[id="sc-74c2715c-6"]{content:"lfhtKZ,"}/*!sc*/
# .hwMXuc{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;height:100%;color:#666666;}/*!sc*/
# data-styled.g76[id="sc-74c2715c-7"]{content:"hwMXuc,"}/*!sc*/
# .iSrzeQ:before{width:1px;height:1.5rem;border-left:1px solid #ddd;content:'';}/*!sc*/
# data-styled.g77[id="sc-74c2715c-8"]{content:"iSrzeQ,"}/*!sc*/
# .eGJmgx{display:block;padding:1.0rem;color:#949494;-webkit-transition:-webkit-transform 150ms ease-in-out;-webkit-transition:transform 150ms ease-in-out;transition:transform 150ms ease-in-out;}/*!sc*/
# .eGJmgx svg{display:block;}/*!sc*/
# .eGJmgx:hover{-webkit-transform:scale(1.025);-ms-transform:scale(1.025);transform:scale(1.025);}/*!sc*/
# .eGJmgx:focus{outline-offset:-2px;}/*!sc*/
# data-styled.g78[id="sc-74c2715c-9"]{content:"eGJmgx,"}/*!sc*/
# .dvKDxQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 1.0rem;height:100%;color:#666666;-webkit-text-decoration:none;text-decoration:none;-webkit-letter-spacing:0.0167rem;-moz-letter-spacing:0.0167rem;-ms-letter-spacing:0.0167rem;letter-spacing:0.0167rem;font-weight:500;font-size:1rem;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;}/*!sc*/
# .dvKDxQ:hover{color:#e61e14;}/*!sc*/
# @media (min-width:1100px){.dvKDxQ{font-size:1.125rem;}}/*!sc*/
# data-styled.g79[id="sc-74c2715c-10"]{content:"dvKDxQ,"}/*!sc*/
# .hEaMAC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;margin:0;padding:0;height:100%;list-style:none;}/*!sc*/
# data-styled.g80[id="sc-74c2715c-11"]{content:"hEaMAC,"}/*!sc*/
# .cpQyza{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:stretch;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch;margin:0;padding:0;height:100%;list-style:none;}/*!sc*/
# .cpQyza .sc-74c2715c-10{padding:0 0.75rem;}/*!sc*/
# @media (min-width:1100px){.cpQyza .sc-74c2715c-10{padding:0 1.0rem;}}/*!sc*/
# data-styled.g81[id="sc-74c2715c-12"]{content:"cpQyza,"}/*!sc*/
# .hSzDpy{position:absolute;top:4rem;left:0;z-index:2;margin:0;padding:0;list-style:none;}/*!sc*/
# data-styled.g82[id="sc-207cf633-0"]{content:"hSzDpy,"}/*!sc*/
# .jcSkVE{display:block;padding:1rem;background-color:#ffffff;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jcSkVE:not(:focus):not(:active){position:absolute;overflow:hidden;-webkit-clip:rect(0 0 0 0);clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);width:0.0625rem;height:0.0625rem;white-space:nowrap;}/*!sc*/
# data-styled.g83[id="sc-207cf633-1"]{content:"jcSkVE,"}/*!sc*/
# .hEcoIv{top:1.25rem;left:2.25rem;}/*!sc*/
# @media (min-width:900px){.hEcoIv{top:1.25rem;left:7.5rem;}}/*!sc*/
# .hEcoIv .sc-207cf633-1{border-radius:0.375rem;box-shadow:0 0.9375rem 1.875rem 0 rgba(0,0,0,0.15);color:#e61e14;font-weight:700;}/*!sc*/
# .hEcoIv .sc-207cf633-1:focus-visible{outline:0.1875rem solid #e61e14;outline-offset:0.125rem;}/*!sc*/
# data-styled.g84[id="sc-c1360127-0"]{content:"hEcoIv,"}/*!sc*/
# .jRcrrK{position:absolute;top:4rem;right:0;left:0;z-index:3;margin:0;padding:0;list-style:none;}/*!sc*/
# data-styled.g85[id="sc-c3959a71-0"]{content:"jRcrrK,"}/*!sc*/
# .ktGlSL{width:100%;height:100%;}/*!sc*/
# data-styled.g86[id="sc-c3959a71-1"]{content:"ktGlSL,"}/*!sc*/
# .shcfX{top:0;left:0.375rem;}/*!sc*/
# data-styled.g87[id="sc-c3959a71-2"]{content:"shcfX,"}/*!sc*/
# .hoVQiE{overflow:hidden;width:100%;}/*!sc*/
# data-styled.g131[id="sc-e3291b83-0"]{content:"hoVQiE,"}/*!sc*/
# .bpvgNK{position:relative;margin:0 -1.0rem;padding-left:1.0rem;min-width:calc(100% + 2rem);width:calc(100% + 2rem);}/*!sc*/
# @media (min-width:760px){.bpvgNK{margin:0 auto;min-width:100%;width:100%;padding-left:0;-webkit-mask-image:linear-gradient( 90deg, transparent 0%, black 1.5rem, black calc(100% - 1.5rem), transparent 100% );mask-image:linear-gradient( 90deg, transparent 0%, black 1.5rem, black calc(100% - 1.5rem), transparent 100% );}}/*!sc*/
# @media (min-width:1440px){}/*!sc*/
# data-styled.g132[id="sc-e3291b83-1"]{content:"bpvgNK,"}/*!sc*/
# .jfjIGe{-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin:0;padding:0;}/*!sc*/
# data-styled.g133[id="sc-e3291b83-2"]{content:"jfjIGe,"}/*!sc*/
# .eOpQuT{position:absolute;top:0;z-index:1;display:none;padding:0 1.0rem;height:100%;-webkit-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);pointer-events:none;}/*!sc*/
# @media (min-width:760px){.eOpQuT{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;pointer-events:all;}}/*!sc*/
# data-styled.g134[id="sc-e3291b83-3"]{content:"eOpQuT,"}/*!sc*/
# .bBFXem{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-transition:opacity 300ms ease-in-out, left 300ms ease-in-out;transition:opacity 300ms ease-in-out, left 300ms ease-in-out;}/*!sc*/
# .hHKmZJ{padding-top:3.3rem;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-transition:opacity 300ms ease-in-out, left 300ms ease-in-out;transition:opacity 300ms ease-in-out, left 300ms ease-in-out;}/*!sc*/
# data-styled.g135[id="sc-e3291b83-4"]{content:"bBFXem,hHKmZJ,"}/*!sc*/
# .dviFqM{right:0;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-transition:opacity 300ms ease-in-out, right 300ms ease-in-out;transition:opacity 300ms ease-in-out, right 300ms ease-in-out;}/*!sc*/
# .gGQfTX{padding-top:3.3rem;right:0;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-transition:opacity 300ms ease-in-out, right 300ms ease-in-out;transition:opacity 300ms ease-in-out, right 300ms ease-in-out;}/*!sc*/
# data-styled.g136[id="sc-e3291b83-5"]{content:"dviFqM,gGQfTX,"}/*!sc*/
# .bMXDls{margin-bottom:2rem;border-radius:0.25rem;box-shadow:0 2px 8px 0 rgba(0,0,0,0.1);}/*!sc*/
# data-styled.g143[id="sc-f64cc41c-0"]{content:"bMXDls,"}/*!sc*/
# .iuSZTe{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-letter-spacing:0.3px;-moz-letter-spacing:0.3px;-ms-letter-spacing:0.3px;letter-spacing:0.3px;}/*!sc*/
# .iuSZTe:after{content:'';position:absolute;right:0;bottom:0;left:1.0rem;background-color:#eee;height:1px;}/*!sc*/
# .iuSZTe:last-child:after{content:none;}/*!sc*/
# data-styled.g146[id="sc-89385b10-0"]{content:"iuSZTe,"}/*!sc*/
# .fuaKrM{display:none;overflow:hidden;margin-bottom:2rem;padding:0 0.875rem 1.5rem;width:100%;background-color:#f3f3f0;}/*!sc*/
# @media (min-width:760px){.fuaKrM{max-width:75rem;}}/*!sc*/
# data-styled.g215[id="sc-232f6040-0"]{content:"fuaKrM,"}/*!sc*/
# .gQKbzA{display:inline-block;margin:0.75rem 0;width:100%;color:#888888;text-align:center;text-transform:uppercase;-webkit-letter-spacing:0.0625rem;-moz-letter-spacing:0.0625rem;-ms-letter-spacing:0.0625rem;letter-spacing:0.0625rem;font-size:0.875rem;}/*!sc*/
# .gQKbzA a{color:#888888;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;}/*!sc*/
# .gQKbzA a:hover{color:#e61e14;}/*!sc*/
# data-styled.g216[id="sc-232f6040-1"]{content:"gQKbzA,"}/*!sc*/
# .cYwZex{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;background-color:transparent !important;margin:auto;overflow:hidden;}/*!sc*/
# data-styled.g217[id="sc-232f6040-2"]{content:"cYwZex,"}/*!sc*/
# .dmgcQK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-bottom:0.5rem;}/*!sc*/
# @media (min-width:760px){.dmgcQK{margin-bottom:1.0rem;}}/*!sc*/
# data-styled.g349[id="sc-7425666a-0"]{content:"dmgcQK,"}/*!sc*/
# .jNqOCX{margin:0;color:#e61e14;font-weight:500;font-size:1.125rem;font-family:'Effra-Bold',Helvetica,Arial,sans-serif;line-height:1.11;}/*!sc*/
# @media (min-width:760px){.jNqOCX{font-size:1.5rem;}}/*!sc*/
# @media (min-width:900px){.jNqOCX{font-size:1.75rem;}}/*!sc*/
# data-styled.g350[id="sc-7425666a-1"]{content:"jNqOCX,"}/*!sc*/
# .bcYKgE{text-underline-offset:0.1875rem;color:#666666;font-weight:500;font-size:0.75rem;-webkit-transition:color 150ms ease-in-out;transition:color 150ms ease-in-out;}/*!sc*/
# @media (hover:hover) and (pointer:fine),only screen and (-ms-high-contrast:active),(-ms-high-contrast:none){.bcYKgE:hover{color:#e61e14;}}/*!sc*/
# .bcYKgE:active{color:#e61e14;}/*!sc*/
# @media (min-width:760px){.bcYKgE{font-size:0.875rem;text-underline-offset:0.3125rem;}}/*!sc*/
# data-styled.g351[id="sc-7425666a-2"]{content:"bcYKgE,"}/*!sc*/
# .bDUCzv{position:relative;-webkit-flex:0 0 40%;-ms-flex:0 0 40%;flex:0 0 40%;min-width:9.375rem;padding:0 1.0rem 0 0;margin:0;list-style:none;}/*!sc*/
# @media (min-width:760px){.bDUCzv{-webkit-flex:0 0 21%;-ms-flex:0 0 21%;flex:0 0 21%;min-width:12.5rem;padding:0 1.5rem 0 0;}}/*!sc*/
# @media (min-width:900px){.bDUCzv{padding:0 2rem 0 0;}}/*!sc*/
# data-styled.g352[id="sc-7425666a-3"]{content:"bDUCzv,"}/*!sc*/
# .lokwbA{position:relative;}/*!sc*/
# data-styled.g353[id="sc-7425666a-4"]{content:"lokwbA,"}/*!sc*/
# .iesUTF{top:0.625rem;left:0.4375rem;}/*!sc*/
# data-styled.g354[id="sc-7425666a-5"]{content:"iesUTF,"}/*!sc*/
# .idZyQG img{-webkit-transition:-webkit-transform 250ms ease-in-out;-webkit-transition:transform 250ms ease-in-out;transition:transform 250ms ease-in-out;-webkit-transform:perspective(1px) scale3d(1,1,1);-ms-transform:perspective(1px) scale3d(1,1,1);transform:perspective(1px) scale3d(1,1,1);}/*!sc*/
# data-styled.g355[id="sc-6c728684-0"]{content:"idZyQG,"}/*!sc*/
# .hYzhZc{position:relative;-webkit-text-decoration:none;text-decoration:none;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;height:100%;}/*!sc*/
# @media (max-width:760px){.hYzhZc .sc-577f6030-0{padding:0.25rem 0.5rem;font-size:0.75rem;}.hYzhZc .sc-e6b42465-3 .sc-577f6030-0{padding:0 0 0.25rem;}.hYzhZc .sc-2d866c3b-0{font-weight:500;font-size:0.875rem;line-height:1rem;}.hYzhZc .sc-2d866c3b-1{font-size:0.875rem;}.hYzhZc .sc-e6b42465-0{padding-top:0.5rem;}.hYzhZc .sc-e6b42465-0 .sc-2d866c3b-0{font-family:'Helvetica Neue',Helvetica,Arial,sans-serif;}.hYzhZc .sc-7bbb3d29-0{padding:1.0rem;}.hYzhZc .sc-7bbb3d29-0 .sc-2d866c3b-0{font-family:'Effra-Bold',Helvetica,Arial,sans-serif;}.hYzhZc .sc-2d866c3b-3{padding:25% 1.0rem 1.0rem 1.0rem;}.hYzhZc .sc-2d866c3b-2{top:0.5rem;right:0.5rem;padding:0.5rem;width:2rem;height:2rem;}}/*!sc*/
# @media (min-width:760px){.hYzhZc .sc-577f6030-0{padding:0.3125rem 0.625rem;font-size:0.875rem;}.hYzhZc .sc-e6b42465-3 .sc-577f6030-0{margin-top:-0.25rem;padding:0 0 0.25rem;}.hYzhZc .sc-2d866c3b-0{font-weight:700;font-size:1.125rem;font-family:'Effra-Bold',Helvetica,Arial,sans-serif;line-height:1.125rem;}.hYzhZc .sc-2d866c3b-1{font-size:1rem;}.hYzhZc .sc-e6b42465-0{padding-top:1.0rem;}.hYzhZc .sc-7bbb3d29-0{padding:1.0rem;}.hYzhZc .sc-2d866c3b-3{padding:25% 1.0rem 1.0rem 1.0rem;}.hYzhZc .sc-2d866c3b-2{top:0.5rem;right:0.5rem;padding:0.5rem;width:2rem;height:2rem;}}/*!sc*/
# .hYzhZc .sc-e6b42465-0 .sc-e6b42465-2{display:none;}/*!sc*/
# .hYzhZc .sc-e6b42465-1{margin-right:0;padding-top:75%;width:100%;}/*!sc*/
# .hYzhZc .sc-e6b42465-1 .sc-e6b42465-2{position:absolute;bottom:0.5rem;left:0.5rem;display:block;margin-bottom:0;}/*!sc*/
# .hYzhZc:focus{outline-offset:0.125rem;}/*!sc*/
# ...
#       (min-width: 760px) 24vw, (min-width: 375px) 31vw, 38vw" srcset="https://cdn.nos.nl/image/2023/04/19/962165/72x96a.jpg 72w, https://cdn.nos.nl/image/2023/04/19/962165/144x192a.jpg 144w, https://cdn.nos.nl/image/2023/04/19/962165/216x288a.jpg 216w, https://cdn.nos.nl/image/2023/04/19/962165/288x384a.jpg 288w, https://cdn.nos.nl/image/2023/04/19/962165/360x480a.jpg 360w, https://cdn.nos.nl/image/2023/04/19/962165/432x576a.jpg 432w, https://cdn.nos.nl/image/2023/04/19/962165/576x768a.jpg 576w, https://cdn.nos.nl/image/2023/04/19/962165/720x960a.jpg 720w, https://cdn.nos.nl/image/2023/04/19/962165/864x1152a.jpg 864w, https://cdn.nos.nl/image/2023/04/19/962165/1080x1440a.jpg 1080w, https://cdn.nos.nl/image/2023/04/19/962165/1440x1920a.jpg 1440w, https://cdn.nos.nl/image/2023/04/19/962165/1800x2400a.jpg 1800w, https://cdn.nos.nl/image/2023/04/19/962165/2160x2880a.jpg 2160w"/><img alt="" class="sc-8e313b0a-1 dGrJDt" decoding="async" loading="lazy" src="https://cdn.nos.nl/image/2023/04/19/962165/576x768a.jpg"/></picture></div></div></div></li><li class="sc-7425666a-3 sc-88669cf8-0 bDUCzv kluHcE"><div class="sc-6ff8f256-2 rYFYI" data-testid="card-content-inside"><div class="sc-7bbb3d29-0 kDMmdZ"><div class="sc-2d866c3b-3 caEZmW"><div class="sc-577f6030-0 bRxKDw pill-type-video" data-testid="pill-with-label"><svg aria-hidden="true" height="26" viewbox="0 0 26 26" width="26" xmlns="http://www.w3.org/2000/svg"><path d="M22.3 11.76L5.34 1.23C4.33.61 3 1.31 3 2.47v21.06c0 1.16 1.33 1.86 2.33 1.24L22.3 14.24c.93-.58.93-1.9 0-2.47" fill="currentColor" fill-rule="nonzero"></path></svg><span class="sc-577f6030-1 cMNAXz"><time datetime="0m 38s">0:38</time></span></div><h2 class="sc-2d866c3b-0 dypUEp">Le Spiderman</h2></div></div><div class="sc-6ff8f256-1 KJIEE"><div class="sc-8e313b0a-0 qTpqt sc-6ff8f256-0 eNhkUR"><picture><source media="" sizes="(min-width: 1215px) 169px, (min-width: 900px) 15vw,
#       (min-width: 760px) 24vw, (min-width: 375px) 31vw, 38vw" srcset="https://cdn.nos.nl/image/2023/04/19/962133/72x96a.jpg 72w, https://cdn.nos.nl/image/2023/04/19/962133/144x192a.jpg 144w, https://cdn.nos.nl/image/2023/04/19/962133/216x288a.jpg 216w, https://cdn.nos.nl/image/2023/04/19/962133/288x384a.jpg 288w, https://cdn.nos.nl/image/2023/04/19/962133/360x480a.jpg 360w, https://cdn.nos.nl/image/2023/04/19/962133/432x576a.jpg 432w, https://cdn.nos.nl/image/2023/04/19/962133/576x768a.jpg 576w, https://cdn.nos.nl/image/2023/04/19/962133/720x960a.jpg 720w, https://cdn.nos.nl/image/2023/04/19/962133/864x1152a.jpg 864w, https://cdn.nos.nl/image/2023/04/19/962133/1080x1440a.jpg 1080w, https://cdn.nos.nl/image/2023/04/19/962133/1440x1920a.jpg 1440w, https://cdn.nos.nl/image/2023/04/19/962133/1800x2400a.jpg 1800w, https://cdn.nos.nl/image/2023/04/19/962133/2160x2880a.jpg 2160w"/><img alt="" class="sc-8e313b0a-1 dGrJDt" decoding="async" loading="lazy" src="https://cdn.nos.nl/image/2023/04/19/962133/576x768a.jpg"/></picture></div></div></div></li><li class="sc-7425666a-3 sc-88669cf8-0 bDUCzv kluHcE"><div class="sc-6ff8f256-2 rYFYI" data-testid="card-content-inside"><div class="sc-7bbb3d29-0 kDMmdZ"><div class="sc-2d866c3b-3 caEZmW"><div class="sc-577f6030-0 bRxKDw pill-type-video" data-testid="pill-with-label"><svg aria-hidden="true" height="26" viewbox="0 0 26 26" width="26" xmlns="http://www.w3.org/2000/svg"><path d="M22.3 11.76L5.34 1.23C4.33.61 3 1.31 3 2.47v21.06c0 1.16 1.33 1.86 2.33 1.24L22.3 14.24c.93-.58.93-1.9 0-2.47" fill="currentColor" fill-rule="nonzero"></path></svg><span class="sc-577f6030-1 cMNAXz"><time datetime="0m 41s">0:41</time></span></div><h2 class="sc-2d866c3b-0 dypUEp">Kraanvogel</h2></div></div><div class="sc-6ff8f256-1 KJIEE"><div class="sc-8e313b0a-0 qTpqt sc-6ff8f256-0 eNhkUR"><picture><source media="" sizes="(min-width: 1215px) 169px, (min-width: 900px) 15vw,
#       (min-width: 760px) 24vw, (min-width: 375px) 31vw, 38vw" srcset="https://cdn.nos.nl/image/2023/04/19/962070/72x96a.jpg 72w, https://cdn.nos.nl/image/2023/04/19/962070/144x192a.jpg 144w, https://cdn.nos.nl/image/2023/04/19/962070/216x288a.jpg 216w, https://cdn.nos.nl/image/2023/04/19/962070/288x384a.jpg 288w, https://cdn.nos.nl/image/2023/04/19/962070/360x480a.jpg 360w, https://cdn.nos.nl/image/2023/04/19/962070/432x576a.jpg 432w, https://cdn.nos.nl/image/2023/04/19/962070/576x768a.jpg 576w, https://cdn.nos.nl/image/2023/04/19/962070/720x960a.jpg 720w, https://cdn.nos.nl/image/2023/04/19/962070/864x1152a.jpg 864w, https://cdn.nos.nl/image/2023/04/19/962070/1080x1440a.jpg 1080w, https://cdn.nos.nl/image/2023/04/19/962070/1440x1920a.jpg 1440w, https://cdn.nos.nl/image/2023/04/19/962070/1800x2400a.jpg 1800w, https://cdn.nos.nl/image/2023/04/19/962070/2160x2880a.jpg 2160w"/><img alt="" class="sc-8e313b0a-1 dGrJDt" decoding="async" loading="lazy" src="https://cdn.nos.nl/image/2023/04/19/962070/576x768a.jpg"/></picture></div></div></div></li><li class="sc-7425666a-3 sc-88669cf8-0 bDUCzv kluHcE"><div class="sc-6ff8f256-2 rYFYI" data-testid="card-content-inside"><div class="sc-7bbb3d29-0 kDMmdZ"><div class="sc-2d866c3b-3 caEZmW"><div class="sc-577f6030-0 bRxKDw pill-type-video" data-testid="pill-with-label"><svg aria-hidden="true" height="26" viewbox="0 0 26 26" width="26" xmlns="http://www.w3.org/2000/svg"><path d="M22.3 11.76L5.34 1.23C4.33.61 3 1.31 3 2.47v21.06c0 1.16 1.33 1.86 2.33 1.24L22.3 14.24c.93-.58.93-1.9 0-2.47" fill="currentColor" fill-rule="nonzero"></path></svg><span class="sc-577f6030-1 cMNAXz"><time datetime="0m 24s">0:24</time></span></div><h2 class="sc-2d866c3b-0 dypUEp">Eindelijk gevonden</h2></div></div><div class="sc-6ff8f256-1 KJIEE"><div class="sc-8e313b0a-0 qTpqt sc-6ff8f256-0 eNhkUR"><picture><source media="" sizes="(min-width: 1215px) 169px, (min-width: 900px) 15vw,
#       (min-width: 760px) 24vw, (min-width: 375px) 31vw, 38vw" srcset="https://cdn.nos.nl/image/2023/04/19/961962/72x96a.jpg 72w, https://cdn.nos.nl/image/2023/04/19/961962/144x192a.jpg 144w, https://cdn.nos.nl/image/2023/04/19/961962/216x288a.jpg 216w, https://cdn.nos.nl/image/2023/04/19/961962/288x384a.jpg 288w, https://cdn.nos.nl/image/2023/04/19/961962/360x480a.jpg 360w, https://cdn.nos.nl/image/2023/04/19/961962/432x576a.jpg 432w, https://cdn.nos.nl/image/2023/04/19/961962/576x768a.jpg 576w, https://cdn.nos.nl/image/2023/04/19/961962/720x960a.jpg 720w, https://cdn.nos.nl/image/2023/04/19/961962/864x1152a.jpg 864w, https://cdn.nos.nl/image/2023/04/19/961962/1080x1440a.jpg 1080w, https://cdn.nos.nl/image/2023/04/19/961962/1440x1920a.jpg 1440w, https://cdn.nos.nl/image/2023/04/19/961962/1800x2400a.jpg 1800w, https://cdn.nos.nl/image/2023/04/19/961962/2160x2880a.jpg 2160w"/><img alt="" class="sc-8e313b0a-1 dGrJDt" decoding="async" loading="lazy" src="https://cdn.nos.nl/image/2023/04/19/961962/576x768a.jpg"/></picture></div></div></div></li></ul></div><div class="sc-e3291b83-3 sc-e3291b83-5 eOpQuT dviFqM" style="opacity:0;right:-1rem"><button aria-label="Volgende slide" class="sc-d9ef4f17-0 bTCccR" type="button"><svg height="18" viewbox="0 0 20 18" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M12.495.894L19.78 8.45a.798.798 0 010 1.1l-7.285 7.555a.73.73 0 01-1.06 0 .798.798 0 010-1.1l6.004-6.227H.75C.336 9.778 0 9.429 0 9c0-.43.336-.778.75-.778h16.689l-6.004-6.228a.798.798 0 010-1.1.732.732 0 011.06 0z" fill="currentColor" fill-rule="nonzero"></path></svg></button></div></div></div><section class="sc-241f4c3-0 bdGuQM"><ul class="sc-241f4c3-1 aMkhq"><li class="sc-d7b70912-0 dyQugA sc-241f4c3-2 gWrgan"><a class="sc-6c728684-1 bxXfpb" href="/artikel/2472366-studentencorps-amsterdam-biedt-leden-excuses-aan-voor-structureel-geweld"><div class="sc-e6b42465-1 eKBpig"><div class="sc-8e313b0a-0 qTpqt sc-6c728684-0 idZyQG"><picture><source media="" sizes="(min-width: 1215px) 240px, (min-width: 900px) 24vw, (min-width: 760px) 33vw, 104px" srcset="https://cdn.nos.nl/image/2023/04/22/962881/96x72a.jpg 96w, https://cdn.nos.nl/image/2023/04/22/962881/192x144a.jpg 192w, https://cdn.nos.nl/image/2023/04/22/962881/288x216a.jpg 288w, https://cdn.nos.nl/image/2023/04/22/962881/384x288a.jpg 384w, https://cdn.nos.nl/image/2023/04/22/962881/480x360a.jpg 480w, https://cdn.nos.nl/image/2023/04/22/962881/576x432a.jpg 576w, https://cdn.nos.nl/image/2023/04/22/962881/768x576a.jpg 768w, https://cdn.nos.nl/image/2023/04/22/962881/960x720a.jpg 960w, https://cdn.nos.nl/image/2023/04/22/962881/1152x864a.jpg 1152w, https://cdn.nos.nl/image/2023/04/22/962881/1440x1080a.jpg 1440w, https://cdn.nos.nl/image/2023/04/22/962881/1920x1440a.jpg 1920w, https://cdn.nos.nl/image/2023/04/22/962881/2400x1800a.jpg 2400w, https://cdn.nos.nl/image/2023/04/22/962881/2880x2160a.jpg 2880w"/><img alt="" class="sc-8e313b0a-1 dGrJDt" decoding="async" loading="lazy" src="https://cdn.nos.nl/image/2023/04/22/962881/768x576a.jpg"/></picture></div></div><div class="sc-e6b42465-0 PkRtd"><h2 class="sc-2d866c3b-0 dypUEp">Studentencorps Amsterdam biedt leden excuses aan voor structureel geweld</h2><p class="sc-2d866c3b-1 jPkGEE">Een advocatenkantoor heeft op verzoek van het corps onderzoek gedaan naar de ontgroeningspraktijken.</p></div></a></li><li class="sc-d7b70912-0 dyQugA sc-241f4c3-2 gWrgan"><a class="sc-6c728684-1 bxXfpb" href="/artikel/2472370-schrik-voor-pogacar-niet-bij-evenepoel-al-onze-renners-kunnen-luik-zondag-winnen"><div class="sc-e6b42465-1 eKBpig"><div class="sc-8e313b0a-0 qTpqt sc-6c728684-0 idZyQG"><picture><source media="" sizes="(min-width: 1215px) 240px, (min-width: 900px) 24vw, (min-width: 760px) 33vw, 104px" srcset="https://cdn.nos.nl/image/2023/04/22/962884/96x72a.jpg 96w, https://cdn.nos.nl/image/2023/04/22/962884/192x144a.jpg 192w, https://cdn.nos.nl/image/2023/04/22/962884/288x216a.jpg 288w, https://cdn.nos.nl/image/2023/04/22/962884/384x288a.jpg 384w, h ...
#   var ccmWrapperElement = document.createElement('script');
#   ccmWrapperElement.crossOrigin = 'anonymous';
#   ccmWrapperElement.src = 'https://cookies.nos.nl/sites/NOS/nos.nl/ccm-wrapper_v1.1.js';
#   ccmWrapperElement.async = true;
#   ccmWrapperElement.defer = true;
#   var s = document.getElementsByTagName('script')[0];
#   s.parentNode.insertBefore(ccmWrapperElement, s);
#   window.addEventListener('CCM_Wrapper_ready', function () {
#     ccmWrapper.init();
#   });
# })();</script><script src="//imasdk.googleapis.com/js/sdkloader/ima3.js"></script></div><script id="__NEXT_DATA__" type="application/json">{"props":{"hostname":"prod-app","broadcasters":[{"slug":"limburg","name":"L1mburg","iconSrc":"https://static.nos.nl/regio/logos/Limburg/Regio_Limburg.svg","url":"https://www.1Limburg.nl"},{"slug":"noord-holland","name":"NH Nieuws","iconSrc":"https://static.nos.nl/regio/logos/NH/Regio_NH.svg","url":"https://nhnieuws.nl"},{"slug":"brabant","name":"Omroep Brabant","iconSrc":"https://static.nos.nl/regio/logos/Brabant/Regio_brabant.svg","url":"https://www.omroepbrabant.nl"},{"slug":"flevoland","name":"Omroep Flevoland","iconSrc":"https://static.nos.nl/regio/logos/Flevoland/Regio_Flevoland.svg","url":"https://www.omroepflevoland.nl"},{"slug":"friesland","name":"Omrop Fryslân","iconSrc":"https://static.nos.nl/regio/logos/Friesland/Regio_Friesland.svg","url":"https://www.omropfryslan.nl"},{"slug":"gelderland","name":"Omroep Gelderland","iconSrc":"https://static.nos.nl/regio/logos/Gelderland/Regio_Gelderland.svg","url":"https://www.gld.nl"},{"slug":"zh-west","name":"Omroep West","iconSrc":"https://static.nos.nl/regio/logos/ZH-West/Regio_ZH-West.svg","url":"https://www.omroepwest.nl"},{"slug":"zeeland","name":"Omroep Zeeland","iconSrc":"https://static.nos.nl/regio/logos/Zeeland/Regio_zeeland.svg","url":"https://www.omroepzeeland.nl"},{"slug":"zh-rijnmond","name":"Rijnmond","iconSrc":"https://static.nos.nl/regio/logos/ZH-Rijnmond/Regio_ZH-Rijnmond.svg","url":"https://www.rijnmond.nl"},{"slug":"drenthe","name":"RTV Drenthe","iconSrc":"https://static.nos.nl/regio/logos/Drenthe/Regio_drenthe.svg","url":"https://www.rtvdrenthe.nl"},{"slug":"groningen","name":"RTV Noord","iconSrc":"https://static.nos.nl/regio/logos/Groningen/Regio_Groningen.svg","url":"https://www.rtvnoord.nl"},{"slug":"overijssel","name":"RTV Oost","iconSrc":"https://static.nos.nl/regio/logos/Overijssel/Regio_overijssel.svg","url":"https://www.rtvoost.nl"},{"slug":"utrecht","name":"RTV Utrecht","iconSrc":"https://static.nos.nl/regio/logos/Utrecht/Regio_Utrecht.svg","url":"https://www.rtvutrecht.nl"}],"pageProps":{"_sentryTraceData":"b97236ae407242048fcd1de2108ce6b6-aac3509aa76cf413-0","_sentryBaggage":"sentry-environment=production,sentry-release=production%4013.5.2,sentry-transaction=%2F,sentry-public_key=3caf4fd1080f42859504caf5189fa266,sentry-trace_id=b97236ae407242048fcd1de2108ce6b6,sentry-sample_rate=0","isMobile":false,"featuredItems":[{"id":2472371,"title":"Run op lastminutes door matig lenteweer, maar dagjesmensen blijven niet weg","systemTag":null,"imagesByRatio":{"4:3":[{"width":96,"height":72,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/962885/96x72a.jpg"}},{"width":192,"height":144,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/962885/192x144a.jpg"}},{"width":288,"height":216,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/962885/288x216a.jpg"}},{"width":384,"height":288,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/962885/384x288a.jpg"}},{"width":480,"height":360,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/962885/480x360a.jpg"}},{"width":576,"height":432,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/962885/576x432a.jpg"}},{"width":768,"height":576,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/962885/768x576a.jpg"}},{"width":960,"height":720,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/962885/960x720a.jpg"}},{"width":1152,"height":864,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/962885/1152x864a.jpg"}},{"width":1440,"height":1080,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/962885/1440x1080a.jpg"}},{"width":1920,"height":1440,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/962885/1920x1440a.jpg"}},{"width":2400,"height":1800,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/962885/2400x1800a.jpg"}},{"width":2880,"height":2160,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/962885/2880x2160a.jpg"}}],"16:9":[{"width":128,"height":72,"url":{"jpg":"https://cdn.nos.nl/image/2023/04/22/ ...

# %%
# News identification
coverpage_headlines = soup.find_all('h2', class_='sc-2d866c3b-0 dypUEp')
len(coverpage_headlines)
# Out:
# 107

# %% [markdown]
# Now we have a list in which every element is a news article:

# %%
coverpage_headlines[0]
# Out:
# <h2 class="sc-2d866c3b-0 dypUEp">Run op lastminutes door matig lenteweer, maar dagjesmensen blijven niet weg</h2>

# %%
n=0
title = coverpage_headlines[n].get_text()
title
# Out:
# 'Run op lastminutes door matig lenteweer, maar dagjesmensen blijven niet weg'

# %%
coverpage_body = soup.find_all('p', class_='sc-2d866c3b-1 jPkGEE')
coverpage_body
# Out:
# [<p class="sc-2d866c3b-1 jPkGEE">Niemand raakte gewond. De snelweg tussen Breukelen en Vinkeveen werd geheel afgesloten.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">Amerikaanse torpedo's joegen het Japanse schip in 1942 naar de zeebodem. De Amerikanen wisten niet dat er Australische krijgsgevangenen aan boord waren. Het wrak ligt op 4000 meter diepte.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">Steeds meer landen maken zich op om hun burgers uit het land te evacueren. Dat is echter lastig omdat het vliegveld bij de hoofdstad gesloten is.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">De tweevoudig olympisch kampioene heeft bewust gekozen voor de prestigieuze marathon van Londen, waar zondag de complete wereldtop van start gaat. "Dit is wat ze wilde. Ze wil tegen de besten lopen", zegt manager Jos Hermens.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">Hoewel de precieze prijs verschilt per pomp, is het volgens analisten duidelijk dat de prijs niet snel weer zal zakken en waarschijnlijk zelfs verder stijgt.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">In dit liveblog lees je de belangrijkste ontwikkelingen rond de oorlog in Oekraïne.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">Er vielen daarnaast tien gewonden, waarvan er zes ernstig aan toe zijn. </p>,
#  <p class="sc-2d866c3b-1 jPkGEE">Wrexham AFC staat op het punt te promoveren naar de League Two. De club van eigenaren Ryan Reynolds en Rob McElhenney kende de laatste jaren niet alleen sportieve groei.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">De arrestatie van strafrechtadvocaat Inez Weski heeft voor geschokte reacties gezorgd. Vooral over de timing van het OM. </p>,
#  <p class="sc-2d866c3b-1 jPkGEE">Een advocatenkantoor heeft op verzoek van het corps onderzoek gedaan naar de ontgroeningspraktijken.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">De Belg is in voorbereiding op de Giro die op 6 mei van start gaat en zegt, zonder ook maar een wedstrijd gereden te hebben in een maand, dicht tegen zijn beste vorm aan te zitten.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">De jonge fietser werd op weg naar school doodgereden door een trucker. Zijn moeder zegt al meermalen te hebben aangegeven dat de situatie levensgevaarlijk is.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">In aanloop naar de eredivisiewedstrijd tegen PSV gaat de aanvoerder van Ajax in op de strijd om plek twee, het teleurstellende seizoen van Ajax en zijn toekomst in Amsterdam. </p>,
#  <p class="sc-2d866c3b-1 jPkGEE">Een federale rechter legde eerder deze maand een verbod op mifepriston op in een zaak die was aangespannen door anti-abortusbewegingen. President Biden heeft dat nu succesvol aangevochten.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">Hassan Diab, van Palestijnse afkomst, zou als student een aanslag hebben gepleegd bij een synagoge. Vier mensen kwamen om. Diab spreekt de beschuldigingen tegen.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">In Sudan woedt sinds afgelopen zaterdag de strijd tussen het Sudanese regeringsleger en de paramilitaire groep Rapid Support Forces. </p>,
#  <p class="sc-2d866c3b-1 jPkGEE">Honderden voetbalfans bezongen de spelersgroep en staken vuurwerk af, nadat de ploeg zich eerder op de avond had verzekerd van promotie naar de eredivisie.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">In het blad leek het alsof de Duitser voor het eerst sinds zijn ernstige skiongeluk in 2013 met de media had gesproken. </p>,
#  <p class="sc-2d866c3b-1 jPkGEE">De onweersbuien die gisteravond over Nederland trokken hebben op diverse plekken geleid tot overlast.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">Nieuws, weer, verkeer: met dit overzicht begin je geïnformeerd aan je dag.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">Thomas van den Belt kopt een kwartier voor tijd de gelijkmaker binnen voor Zwolle tegen Almere City.</p>,
#  <p class="sc-2d866c3b-1 jPkGEE">Alejandro Toledo wordt in Peru verdacht van corruptie tijdens zijn presidentschap, al spreekt hij de beschuldigingen tegen. Hij woont al jaren in de Verenigde Staten.</p>]

# %%
len(coverpage_body)
# Out:
# 22

# %%
coverpage_body[0].get_text()
# Out:
# 'Niemand raakte gewond. De snelweg tussen Breukelen en Vinkeveen werd geheel afgesloten.'

# %% [markdown]
# ### Let's extract the text from the articles:

# %% [markdown]
# First, we'll define the number of articles we want:

# %%
number_of_articles = 10

# %%
# Empty lists for content, links and titles
news_headlines = []
news_content = []

for n in np.arange(0, number_of_articles):
    
    # Getting the title
    headline = coverpage_headlines[n].get_text()
    news_headlines.append(headline)
    
    # Reading the content (divided in paragraphs)
    content = coverpage_body[n].get_text()
    news_content.append(content)

# %%
coverpage_body[0]
# Out:
# <p class="sc-2d866c3b-1 jPkGEE">Niemand raakte gewond. De snelweg tussen Breukelen en Vinkeveen werd geheel afgesloten.</p>

# %% [markdown]
# Let's put them into:
# * a dataset which will the input of the models (`df_features`)
# * a dataset with the title and the link (`df_show_info`)

# %%
# creating a df
news_headlines = pd.DataFrame(
    {'Article Headline': news_headlines})

# creating a df
news_content = pd.DataFrame(
     {'Article Content': news_content})

# %%
news_headlines = news_headlines.drop_duplicates()
news_headlines
# Out:
#                                     Article Headline
# 0  Run op lastminutes door matig lenteweer, maar ...
# 1  BBB kiest in provincie voor VVD, PvdA en zelfs...
# 3          Touringcar brandt uit op A2 bij Breukelen
# 5  Scheepswrak met ruim 1000 slachtoffers WO II n...
# 6  Gevechten in Sudan barsten weer los na kort st...
# 7  Hassan bij marathondebuut tegen wereldtop: 'Ge...
# 8       Weer hogere prijs aan de pomp: hoe komt het?
# 9  Al bij start oorlog informatie gelekt • Russis...

# %%
news_content
# Out:
#                                      Article Content
# 0  Niemand raakte gewond. De snelweg tussen Breuk...
# 1  Amerikaanse torpedo's joegen het Japanse schip...
# 2  Steeds meer landen maken zich op om hun burger...
# 3  De tweevoudig olympisch kampioene heeft bewust...
# 4  Hoewel de precieze prijs verschilt per pomp, i...
# 5  In dit liveblog lees je de belangrijkste ontwi...
# 6  Er vielen daarnaast tien gewonden, waarvan er ...
# 7  Wrexham AFC staat op het punt te promoveren na...
# 8  De arrestatie van strafrechtadvocaat Inez Wesk...
# 9  Een advocatenkantoor heeft op verzoek van het ...
